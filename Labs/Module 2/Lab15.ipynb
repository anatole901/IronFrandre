# %% [markdown]
# Lab 15 Combinatorics
#
# Challenge 1. Write a Python program to print all permutations of the string "Ironhack"

# %%
def permutations(s) :
    if s == '' :
        return ['']
    else :
        return [sub + s[i] for i in range(len(s)) for sub in permutations(s[:i] + s[i+1:])]

# %%
permutations('Ironhack')
# Out:
# ['kcahnorI',
#  'ckahnorI',
#  'kachnorI',
#  'akchnorI',
#  'cakhnorI',
#  'ackhnorI',
#  'kchanorI',
#  'ckhanorI',
#  'khcanorI',
#  'hkcanorI',
#  'chkanorI',
#  'hckanorI',
#  'kahcnorI',
#  'akhcnorI',
#  'khacnorI',
#  'hkacnorI',
#  'ahkcnorI',
#  'hakcnorI',
#  'cahknorI',
#  'achknorI',
#  'chaknorI',
#  'hcaknorI',
#  'ahcknorI',
#  'hacknorI',
#  'kcanhorI',
#  'ckanhorI',
#  'kacnhorI',
#  'akcnhorI',
#  'caknhorI',
#  'acknhorI',
#  'kcnahorI',
#  'cknahorI',
#  'kncahorI',
#  'nkcahorI',
#  'cnkahorI',
#  'nckahorI',
#  'kanchorI',
#  'aknchorI',
#  'knachorI',
#  'nkachorI',
#  'ankchorI',
#  'nakchorI',
#  'cankhorI',
#  'acnkhorI',
#  'cnakhorI',
#  'ncakhorI',
#  'anckhorI',
#  'nackhorI',
#  'kchnaorI',
#  'ckhnaorI',
#  'khcnaorI',
#  'hkcnaorI',
#  'chknaorI',
#  'hcknaorI',
#  'kcnhaorI',
#  'cknhaorI',
#  'knchaorI',
#  'nkchaorI',
#  'cnkhaorI',
#  'nckhaorI',
#  'khncaorI',
#  'hkncaorI',
#  'knhcaorI',
#  'nkhcaorI',
#  'hnkcaorI',
#  'nhkcaorI',
#  'chnkaorI',
#  'hcnkaorI',
#  'cnhkaorI',
#  'nchkaorI',
#  'hnckaorI',
#  'nhckaorI',
#  'kahncorI',
#  'akhncorI',
#  'khancorI',
#  'hkancorI',
#  'ahkncorI',
#  'hakncorI',
#  'kanhcorI',
#  'aknhcorI',
#  'knahcorI',
#  'nkahcorI',
#  'ankhcorI',
#  'nakhcorI',
#  'khnacorI',
#  'hknacorI',
#  'knhacorI',
#  'nkhacorI',
#  'hnkacorI',
#  'nhkacorI',
#  'ahnkcorI',
#  'hankcorI',
#  'anhkcorI',
#  'nahkcorI',
#  'hnakcorI',
#  'nhakcorI',
#  'cahnkorI',
#  'achnkorI',
#  'chankorI',
#  'hcankorI',
#  'ahcnkorI',
#  'hacnkorI',
#  'canhkorI',
#  'acnhkorI',
#  'cnahkorI',
#  'ncahkorI',
#  'anchkorI',
#  'nachkorI',
#  'chnakorI',
#  'hcnakorI',
#  'cnhakorI',
#  'nchakorI',
#  'hncakorI',
#  'nhcakorI',
#  'ahnckorI',
#  'hanckorI',
#  'anhckorI',
#  'nahckorI',
#  'hnackorI',
#  'nhackorI',
#  'kcahonrI',
#  'ckahonrI',
#  'kachonrI',
#  'akchonrI',
#  'cakhonrI',
#  'ackhonrI',
#  'kchaonrI',
#  'ckhaonrI',
#  'khcaonrI',
#  'hkcaonrI',
#  'chkaonrI',
#  'hckaonrI',
#  'kahconrI',
#  'akhconrI',
#  'khaconrI',
#  'hkaconrI',
#  'ahkconrI',
#  'hakconrI',
#  'cahkonrI',
#  'achkonrI',
#  'chakonrI',
#  'hcakonrI',
#  'ahckonrI',
#  'hackonrI',
#  'kcaohnrI',
#  'ckaohnrI',
#  'kacohnrI',
#  'akcohnrI',
#  'cakohnrI',
#  'ackohnrI',
#  'kcoahnrI',
#  'ckoahnrI',
#  'kocahnrI',
#  'okcahnrI',
#  'cokahnrI',
#  'ockahnrI',
#  'kaochnrI',
#  'akochnrI',
#  'koachnrI',
#  'okachnrI',
#  'aokchnrI',
#  'oakchnrI',
#  'caokhnrI',
#  'acokhnrI',
#  'coakhnrI',
#  'ocakhnrI',
#  'aockhnrI',
#  'oackhnrI',
#  'kchoanrI',
#  'ckhoanrI',
#  'khcoanrI',
#  'hkcoanrI',
#  'chkoanrI',
#  'hckoanrI',
#  'kcohanrI',
#  'ckohanrI',
#  'kochanrI',
#  'okchanrI',
#  'cokhanrI',
#  'ockhanrI',
#  'khocanrI',
#  'hkocanrI',
#  'kohcanrI',
#  'okhcanrI',
#  'hokcanrI',
#  'ohkcanrI',
#  'chokanrI',
#  'hcokanrI',
#  'cohkanrI',
#  'ochkanrI',
#  'hockanrI',
#  'ohckanrI',
#  'kahocnrI',
#  'akhocnrI',
#  'khaocnrI',
#  'hkaocnrI',
#  'ahkocnrI',
#  'hakocnrI',
#  'kaohcnrI',
#  'akohcnrI',
#  'koahcnrI',
#  'okahcnrI',
#  'aokhcnrI',
#  'oakhcnrI',
#  'khoacnrI',
#  'hkoacnrI',
#  'kohacnrI',
#  'okhacnrI',
#  'hokacnrI',
#  'ohkacnrI',
#  'ahokcnrI',
#  'haokcnrI',
#  'aohkcnrI',
#  'oahkcnrI',
#  'hoakcnrI',
#  'ohakcnrI',
#  'cahoknrI',
#  'achoknrI',
#  'chaoknrI',
#  'hcaoknrI',
#  'ahcoknrI',
#  'hacoknrI',
#  'caohknrI',
#  'acohknrI',
#  'coahknrI',
#  'ocahknrI',
#  'aochknrI',
#  'oachknrI',
#  'choaknrI',
#  'hcoaknrI',
#  'cohaknrI',
#  'ochaknrI',
#  'hocaknrI',
#  'ohcaknrI',
#  'ahocknrI',
#  'haocknrI',
#  'aohcknrI',
#  'oahcknrI',
#  'hoacknrI',
#  'ohacknrI',
#  'kcanohrI',
#  'ckanohrI',
#  'kacnohrI',
#  'akcnohrI',
#  'caknohrI',
#  'acknohrI',
#  'kcnaohrI',
#  'cknaohrI',
#  'kncaohrI',
#  'nkcaohrI',
#  'cnkaohrI',
#  'nckaohrI',
#  'kancohrI',
#  'akncohrI',
#  'knacohrI',
#  'nkacohrI',
#  'ankcohrI',
#  'nakcohrI',
#  'cankohrI',
#  'acnkohrI',
#  'cnakohrI',
#  'ncakohrI',
#  'anckohrI',
#  'nackohrI',
#  'kcaonhrI',
#  'ckaonhrI',
#  'kaconhrI',
#  'akconhrI',
#  'cakonhrI',
#  'ackonhrI',
#  'kcoanhrI',
#  'ckoanhrI',
#  'kocanhrI',
#  'okcanhrI',
#  'cokanhrI',
#  'ockanhrI',
#  'kaocnhrI',
#  'akocnhrI',
#  'koacnhrI',
#  'okacnhrI',
#  'aokcnhrI',
#  'oakcnhrI',
#  'caoknhrI',
#  'acoknhrI',
#  'coaknhrI',
#  'ocaknhrI',
#  'aocknhrI',
#  'oacknhrI',
#  'kcnoahrI',
#  'cknoahrI',
#  'kncoahrI',
#  'nkcoahrI',
#  'cnkoahrI',
#  'nckoahrI',
#  'kconahrI',
#  'ckonahrI',
#  'kocnahrI',
#  'okcnahrI',
#  'coknahrI',
#  'ocknahrI',
#  'knocahrI',
#  'nkocahrI',
#  'koncahrI',
#  'okncahrI',
#  'nokcahrI',
#  'onkcahrI',
#  'cnokahrI',
#  'ncokahrI',
#  'conkahrI',
#  'ocnkahrI',
#  'nockahrI',
#  'onckahrI',
#  'kanochrI',
#  'aknochrI',
#  'knaochrI',
#  'nkaochrI',
#  'ankochrI',
#  'nakochrI',
#  'kaonchrI',
#  'akonchrI',
#  'koanchrI',
#  'okanchrI',
#  'aoknchrI',
#  'oaknchrI',
#  'knoachrI',
#  'nkoachrI',
#  'konachrI',
#  'oknachrI',
#  'nokachrI',
#  'onkachrI',
#  'anokchrI',
#  'naokchrI',
#  'aonkchrI',
#  'oankchrI',
#  'noakchrI',
#  'onakchrI',
#  'canokhrI',
#  'acnokhrI',
#  'cnaokhrI',
#  'ncaokhrI',
#  'ancokhrI',
#  'nacokhrI',
#  'caonkhrI',
#  'aconkhrI',
#  'coankhrI',
#  'ocankhrI',
#  'aocnkhrI',
#  'oacnkhrI',
#  'cnoakhrI',
#  'ncoakhrI',
#  'conakhrI',
#  'ocnakhrI',
#  'nocakhrI',
#  'oncakhrI',
#  'anockhrI',
#  'naockhrI',
#  'aonckhrI',
#  'oanckhrI',
#  'noackhrI',
#  'onackhrI',
#  'kchnoarI',
#  'ckhnoarI',
#  'khcnoarI',
#  'hkcnoarI',
#  'chknoarI',
#  'hcknoarI',
#  'kcnhoarI',
#  'cknhoarI',
#  'knchoarI',
#  'nkchoarI',
#  'cnkhoarI',
#  'nckhoarI',
#  'khncoarI',
#  'hkncoarI',
#  'knhcoarI',
#  'nkhcoarI',
#  'hnkcoarI',
#  'nhkcoarI',
#  'chnkoarI',
#  'hcnkoarI',
#  'cnhkoarI',
#  'nchkoarI',
#  'hnckoarI',
#  'nhckoarI',
#  'kchonarI',
#  'ckhonarI',
#  'khconarI',
#  'hkconarI',
#  'chkonarI',
#  'hckonarI',
#  'kcohnarI',
#  'ckohnarI',
#  'kochnarI',
#  'okchnarI',
#  'cokhnarI',
#  'ockhnarI',
#  'khocnarI',
#  'hkocnarI',
#  'kohcnarI',
#  'okhcnarI',
#  'hokcnarI',
#  'ohkcnarI',
#  'choknarI',
#  'hcoknarI',
#  'cohknarI',
#  'ochknarI',
#  'hocknarI',
#  'ohcknarI',
#  'kcnoharI',
#  'cknoharI',
#  'kncoharI',
#  'nkcoharI',
#  'cnkoharI',
#  'nckoharI',
#  'kconharI',
#  'ckonharI',
#  'kocnharI',
#  'okcnharI',
#  'coknharI',
#  'ocknharI',
#  'knocharI',
#  'nkocharI',
#  'koncharI',
#  'okncharI',
#  'nokcharI',
#  'onkcharI',
#  'cnokharI',
#  'ncokharI',
#  'conkharI',
#  'ocnkharI',
#  'nockharI',
#  'onckharI',
#  'khnocarI',
#  'hknocarI',
#  'knhocarI',
#  'nkhocarI',
#  'hnkocarI',
#  'nhkocarI',
#  'khoncarI',
#  'hkoncarI',
#  'kohncarI',
#  'okhncarI',
#  'hokncarI',
#  'ohkncarI',
#  'knohcarI',
#  'nkohcarI',
#  'konhcarI',
#  'oknhcarI',
#  'nokhcarI',
#  'onkhcarI',
#  'hnokcarI',
#  'nhokcarI',
#  'honkcarI',
#  'ohnkcarI',
#  'nohkcarI',
#  'onhkcarI',
#  'chnokarI',
#  'hcnokarI',
#  'cnhokarI',
#  'nchokarI',
#  'hncokarI',
#  'nhcokarI',
#  'chonkarI',
#  'hconkarI',
#  'cohnkarI',
#  'ochnkarI',
#  'hocnkarI',
#  'ohcnkarI',
#  'cnohkarI',
#  'ncohkarI',
#  'conhkarI',
#  'ocnhkarI',
#  'nochkarI',
#  'onchkarI',
#  'hnockarI',
#  'nhockarI',
#  'honckarI',
#  'ohnckarI',
#  'nohckarI',
#  'onhckarI',
#  'kahnocrI',
#  'akhnocrI',
#  'khanocrI',
#  'hkanocrI',
#  'ahknocrI',
#  'haknocrI',
#  'kanhocrI',
#  'aknhocrI',
#  'knahocrI',
#  'nkahocrI',
#  'ankhocrI',
#  'nakhocrI',
#  'khnaocrI',
#  'hknaocrI',
#  'knhaocrI',
#  'nkhaocrI',
#  'hnkaocrI',
#  'nhkaocrI',
#  'ahnkocrI',
#  'hankocrI',
#  'anhkocrI',
#  'nahkocrI',
#  'hnakocrI',
#  'nhakocrI',
#  'kahoncrI',
#  'akhoncrI',
#  'khaoncrI',
#  'hkaoncrI',
#  'ahkoncrI',
#  'hakoncrI',
#  'kaohncrI',
#  'akohncrI',
#  'koahncrI',
#  'okahncrI',
#  'aokhncrI',
#  'oakhncrI',
#  'khoancrI',
#  'hkoancrI',
#  'kohancrI',
#  'okhancrI',
#  'hokancrI',
#  'ohkancrI',
#  'ahokncrI',
#  'haokncrI',
#  'aohkncrI',
#  'oahkncrI',
#  'hoakncrI',
#  'ohakncrI',
#  'kanohcrI',
#  'aknohcrI',
#  'knaohcrI',
#  'nkaohcrI',
#  'ankohcrI',
#  'nakohcrI',
#  'kaonhcrI',
#  'akonhcrI',
#  'koanhcrI',
#  'okanhcrI',
#  'aoknhcrI',
#  'oaknhcrI',
#  'knoahcrI',
#  'nkoahcrI',
#  'konahcrI',
#  'oknahcrI',
#  'nokahcrI',
#  'onkahcrI',
#  'anokhcrI',
#  'naokhcrI',
#  'aonkhcrI',
#  'oankhcrI',
#  'noakhcrI',
#  'onakhcrI',
#  'khnoacrI',
#  'hknoacrI',
#  'knhoacrI',
#  'nkhoacrI',
#  'hnkoacrI',
#  'nhkoacrI',
#  'khonacrI',
#  'hkonacrI',
#  'kohnacrI',
#  'okhnacrI',
#  'hoknacrI',
#  'ohknacrI',
#  'knohacrI',
#  'nkohacrI',
#  'konhacrI',
#  'oknhacrI',
#  'nokhacrI',
#  'onkhacrI',
#  'hnokacrI',
#  'nhokacrI',
#  'honkacrI',
#  'ohnkacrI',
#  'nohkacrI',
#  'onhkacrI',
#  'ahnokcrI',
#  'hanokcrI',
#  'anhokcrI',
#  'nahokcrI',
#  'hnaokcrI',
#  'nhaokcrI',
#  'ahonkcrI',
#  'haonkcrI',
#  'aohnkcrI',
#  'oahnkcrI',
#  'hoankcrI',
#  'ohankcrI',
#  'anohkcrI',
#  'naohkcrI',
#  'aonhkcrI',
#  'oanhkcrI',
#  'noahkcrI',
#  'onahkcrI',
#  'hnoakcrI',
#  'nhoakcrI',
#  'honakcrI',
#  'ohnakcrI',
#  'nohakcrI',
#  'onhakcrI',
#  'cahnokrI',
#  'achnokrI',
#  'chanokrI',
#  'hcanokrI',
#  'ahcnokrI',
#  'hacnokrI',
#  'canhokrI',
#  'acnhokrI',
#  'cnahokrI',
#  'ncahokrI',
#  'anchokrI',
#  'nachokrI',
#  'chnaokrI',
#  'hcnaokrI',
#  'cnhaokrI',
#  'nchaokrI',
#  'hncaokrI',
#  'nhcaokrI',
#  'ahncokrI',
#  'hancokrI',
#  'anhcokrI',
#  'nahcokrI',
#  'hnacokrI',
#  'nhacokrI',
#  'cahonkrI',
#  'achonkrI',
#  'chaonkrI',
#  'hcaonkrI',
#  'ahconkrI',
#  'haconkrI',
#  'caohnkrI',
#  'acohnkrI',
#  'coahnkrI',
#  'ocahnkrI',
#  'aochnkrI',
#  'oachnkrI',
#  'choankrI',
#  'hcoankrI',
#  'cohankrI',
#  'ochankrI',
#  'hocankrI',
#  'ohcankrI',
#  'ahocnkrI',
#  'haocnkrI',
#  'aohcnkrI',
#  'oahcnkrI',
#  'hoacnkrI',
#  'ohacnkrI',
#  'canohkrI',
#  'acnohkrI',
#  'cnaohkrI',
#  'ncaohkrI',
#  'ancohkrI',
#  'nacohkrI',
#  'caonhkrI',
#  'aconhkrI',
#  'coanhkrI',
#  'ocanhkrI',
#  'aocnhkrI',
#  'oacnhkrI',
#  'cnoahkrI',
#  'ncoahkrI',
#  'conahkrI',
#  'ocnahkrI',
#  'nocahkrI',
#  'oncahkrI',
#  'anochkrI',
#  'naochkrI',
#  'aonchkrI',
#  'oanchkrI',
#  'noachkrI',
#  'onachkrI',
#  'chnoakrI',
#  'hcnoakrI',
#  'cnhoakrI',
#  'nchoakrI',
#  'hncoakrI',
#  'nhcoakrI',
#  'chonakrI',
#  'hconakrI',
#  'cohnakrI',
#  'ochnakrI',
#  'hocnakrI',
#  'ohcnakrI',
#  'cnohakrI',
#  'ncohakrI',
#  'conhakrI',
#  'ocnhakrI',
#  'nochakrI',
#  'onchakrI',
#  'hnocakrI',
#  'nhocakrI',
#  'honcakrI',
#  'ohncakrI',
#  'nohcakrI',
#  'onhcakrI',
#  'ahnockrI',
#  'hanockrI',
#  'anhockrI',
#  'nahockrI',
#  'hnaockrI',
#  'nhaockrI',
#  'ahonckrI',
#  'haonckrI',
#  'aohnckrI',
#  'oahnckrI',
#  'hoanckrI',
#  'ohanckrI',
#  'anohckrI',
#  'naohckrI',
#  'aonhckrI',
#  'oanhckrI',
#  'noahckrI',
#  'onahckrI',
#  'hnoackrI',
#  'nhoackrI',
#  'honackrI',
#  'ohnackrI',
#  'nohackrI',
#  'onhackrI',
#  'kcahnroI',
#  'ckahnroI',
#  'kachnroI',
#  'akchnroI',
#  'cakhnroI',
#  'ackhnroI',
#  'kchanroI',
#  'ckhanroI',
#  'khcanroI',
#  'hkcanroI',
#  'chkanroI',
#  'hckanroI',
#  'kahcnroI',
#  'akhcnroI',
#  'khacnroI',
#  'hkacnroI',
#  'ahkcnroI',
#  'hakcnroI',
#  'cahknroI',
#  'achknroI',
#  'chaknroI',
#  'hcaknroI',
#  'ahcknroI',
#  'hacknroI',
#  'kcanhroI',
#  'ckanhroI',
#  'kacnhroI',
#  'akcnhroI',
#  'caknhroI',
#  'acknhroI',
#  'kcnahroI',
#  'cknahroI',
#  'kncahroI',
#  'nkcahroI',
#  'cnkahroI',
#  'nckahroI',
#  'kanchroI',
#  'aknchroI',
#  'knachroI',
#  'nkachroI',
#  'ankchroI',
#  'nakchroI',
#  'cankhroI',
#  'acnkhroI',
#  'cnakhroI',
#  'ncakhroI',
#  'anckhroI',
#  'nackhroI',
#  'kchnaroI',
#  'ckhnaroI',
#  'khcnaroI',
#  'hkcnaroI',
#  'chknaroI',
#  'hcknaroI',
#  'kcnharoI',
#  'cknharoI',
#  'kncharoI',
#  'nkcharoI',
#  'cnkharoI',
#  'nckharoI',
#  'khncaroI',
#  'hkncaroI',
#  'knhcaroI',
#  'nkhcaroI',
#  'hnkcaroI',
#  'nhkcaroI',
#  'chnkaroI',
#  'hcnkaroI',
#  'cnhkaroI',
#  'nchkaroI',
#  'hnckaroI',
#  'nhckaroI',
#  'kahncroI',
#  'akhncroI',
#  'khancroI',
#  'hkancroI',
#  'ahkncroI',
#  'hakncroI',
#  'kanhcroI',
#  'aknhcroI',
#  'knahcroI',
#  'nkahcroI',
#  'ankhcroI',
#  'nakhcroI',
#  'khnacroI',
#  'hknacroI',
#  'knhacroI',
#  'nkhacroI',
#  'hnkacroI',
#  'nhkacroI',
#  'ahnkcroI',
#  'hankcroI',
#  'anhkcroI',
#  'nahkcroI',
#  'hnakcroI',
#  'nhakcroI',
#  'cahnkroI',
#  'achnkroI',
#  'chankroI',
#  'hcankroI',
#  'ahcnkroI',
#  'hacnkroI',
#  'canhkroI',
#  'acnhkroI',
#  'cnahkroI',
#  'ncahkroI',
#  'anchkroI',
#  'nachkroI',
#  'chnakroI',
#  'hcnakroI',
#  'cnhakroI',
#  'nchakroI',
#  'hncakroI',
#  'nhcakroI',
#  'ahnckroI',
#  'hanckroI',
#  'anhckroI',
#  'nahckroI',
#  'hnackroI',
#  'nhackroI',
#  'kcahrnoI',
#  'ckahrnoI',
#  'kachrnoI',
#  'akchrnoI',
#  'cakhrnoI',
#  'ackhrnoI',
#  'kcharnoI',
#  'ckharnoI',
#  'khcarnoI',
#  'hkcarnoI',
#  'chkarnoI',
#  'hckarnoI',
#  'kahcrnoI',
#  'akhcrnoI',
#  'khacrnoI',
#  'hkacrnoI',
#  'ahkcrnoI',
#  'hakcrnoI',
#  'cahkrnoI',
#  'achkrnoI',
#  'chakrnoI',
#  'hcakrnoI',
#  'ahckrnoI',
#  'hackrnoI',
#  'kcarhnoI',
#  'ckarhnoI',
#  'kacrhnoI',
#  'akcrhnoI',
#  'cakrhnoI',
#  'ackrhnoI',
#  'kcrahnoI',
#  'ckrahnoI',
#  'krcahnoI',
#  'rkcahnoI',
#  'crkahnoI',
#  'rckahnoI',
#  'karchnoI',
#  'akrchnoI',
#  'krachnoI',
#  'rkachnoI',
#  'arkchnoI',
#  'rakchnoI',
#  'carkhnoI',
#  'acrkhnoI',
#  'crakhnoI',
#  'rcakhnoI',
#  'arckhnoI',
#  'rackhnoI',
#  'kchranoI',
#  'ckhranoI',
#  'khcranoI',
#  'hkcranoI',
#  'chkranoI',
#  'hckranoI',
#  'kcrhanoI',
#  'ckrhanoI',
#  'krchanoI',
#  'rkchanoI',
#  'crkhanoI',
#  'rckhanoI',
#  'khrcanoI',
#  'hkrcanoI',
#  'krhcanoI',
#  'rkhcanoI',
#  'hrkcanoI',
#  'rhkcanoI',
#  'chrkanoI',
#  'hcrkanoI',
#  'crhkanoI',
#  'rchkanoI',
#  'hrckanoI',
#  'rhckanoI',
#  'kahrcnoI',
#  'akhrcnoI',
#  'kharcnoI',
#  'hkarcnoI',
#  'ahkrcnoI',
#  'hakrcnoI',
#  'karhcnoI',
#  'akrhcnoI',
#  'krahcnoI',
#  'rkahcnoI',
#  'arkhcnoI',
#  'rakhcnoI',
#  'khracnoI',
#  'hkracnoI',
#  'krhacnoI',
#  'rkhacnoI',
#  'hrkacnoI',
#  'rhkacnoI',
#  'ahrkcnoI',
#  'harkcnoI',
#  'arhkcnoI',
#  'rahkcnoI',
#  'hrakcnoI',
#  'rhakcnoI',
#  'cahrknoI',
#  'achrknoI',
#  'charknoI',
#  'hcarknoI',
#  'ahcrknoI',
#  'hacrknoI',
#  'carhknoI',
#  'acrhknoI',
#  'crahknoI',
#  'rcahknoI',
#  'archknoI',
#  'rachknoI',
#  'chraknoI',
#  'hcraknoI',
#  'crhaknoI',
#  'rchaknoI',
#  'hrcaknoI',
#  'rhcaknoI',
#  'ahrcknoI',
#  'harcknoI',
#  'arhcknoI',
#  'rahcknoI',
#  'hracknoI',
#  'rhacknoI',
#  'kcanrhoI',
#  'ckanrhoI',
#  'kacnrhoI',
#  'akcnrhoI',
#  'caknrhoI',
#  'acknrhoI',
#  'kcnarhoI',
#  'cknarhoI',
#  'kncarhoI',
#  'nkcarhoI',
#  'cnkarhoI',
#  'nckarhoI',
#  'kancrhoI',
#  'akncrhoI',
#  'knacrhoI',
#  'nkacrhoI',
#  'ankcrhoI',
#  'nakcrhoI',
#  'cankrhoI',
#  'acnkrhoI',
#  'cnakrhoI',
#  'ncakrhoI',
#  'anckrhoI',
#  'nackrhoI',
#  'kcarnhoI',
#  'ckarnhoI',
#  'kacrnhoI',
#  'akcrnhoI',
#  'cakrnhoI',
#  'ackrnhoI',
#  'kcranhoI',
#  'ckranhoI',
#  'krcanhoI',
#  'rkcanhoI',
#  'crkanhoI',
#  'rckanhoI',
#  'karcnhoI',
#  'akrcnhoI',
#  'kracnhoI',
#  'rkacnhoI',
#  ...]

# %% [markdown]
# Challenge 2: How many ways can you choose 3 people from a group of 17 for making the group projects teams?
#
# 3C17 * 3C14 * 3C11 * 3C8 * 3C5 / 5!
#
# Challenge 3: Let's imagine you need to organize the business processes in the coffee shop. You know that each cup can be made from 10 possible ingridients. But it is not profitable to use more than 5 portions of ingridients at once. These ingridients should not be unique (for example, you can put milk twice, and a chocolate onle). How many different variations of coffee you can include to the menu?
#
# 5C14
#
# Challenge 4: Given an array of distinct integers, return all the possible permutations. You can return the answer in any order. The lenght of array and the integers are given by user and may vary

# %%
def lpermutations(l) :
    if l == [] :
        return [[]]
    else :
        return [sub + [l[i]] for i in range(len(l)) for sub in lpermutations(l[:i] + l[i+1:])]

# %%
lpermutations([0, 1, 2, 3])
# Out:
# [[3, 2, 1, 0],
#  [2, 3, 1, 0],
#  [3, 1, 2, 0],
#  [1, 3, 2, 0],
#  [2, 1, 3, 0],
#  [1, 2, 3, 0],
#  [3, 2, 0, 1],
#  [2, 3, 0, 1],
#  [3, 0, 2, 1],
#  [0, 3, 2, 1],
#  [2, 0, 3, 1],
#  [0, 2, 3, 1],
#  [3, 1, 0, 2],
#  [1, 3, 0, 2],
#  [3, 0, 1, 2],
#  [0, 3, 1, 2],
#  [1, 0, 3, 2],
#  [0, 1, 3, 2],
#  [2, 1, 0, 3],
#  [1, 2, 0, 3],
#  [2, 0, 1, 3],
#  [0, 2, 1, 3],
#  [1, 0, 2, 3],
#  [0, 1, 2, 3]]

# %% [markdown]
# Challenge 5: Use intertools library to solve the following problem: Six books are lying on a table in front of you. How many ways can you arrange the books, considering both the left-to-right order of the books and whether they’re set with the front cover facing up or down?
#
# 6! * 2^6
